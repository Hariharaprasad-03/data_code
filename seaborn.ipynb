# %%
import os
import pandas as pd 
import seaborn as sns 
import numpy as np 
from matplotlib import pyplot as plt
import sklearn as sks

# %%
lr=pd.read_csv("C:\\Users\\HARIHARAPRASAD R\\Downloads\\archive (2)\\train.csv")
lr
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
sns.set(style="darkgrid")
sns.regplot(x=lr['x'],y=lr['y'],color='b',fit_reg=True,)
plt.title("linear_regression")
# Out:
# Text(0.5, 1.0, 'linear_regression')

# %%
toyotodf=pd.read_csv("C:\\Users\\HARIHARAPRASAD R\\Downloads\\archive\\scrap price.csv")
toyotodf
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# ...

# %%
tf=toyotodf.select_dtypes(exclude=['object'])
tf.corr()
# Out:
#                         ID  symboling  wheelbase  carlength  carwidth  \
# ID                1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
sns.set(style='darkgrid')
sns.regplot(x=toyotodf['carwidth'],y=toyotodf['price'],data=toyotodf,fit_reg=True)#regression plot
sns.lmplot(x='carwidth',y='price',data=toyotodf,fit_reg=True,hue='fueltypes',legend=True)#lmplot for two variabes regressionplot
# Out:
# c:\Users\HARIHARAPRASAD R\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x='horsepower',y='price',data=toyotodf,fit_reg=True,legend=True)
# Out:
# c:\Users\HARIHARAPRASAD R\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x=toyotodf['carlength'],y=toyotodf['price'])
# Out:
# <Axes: xlabel='carlength', ylabel='price'>

# %%
sns.distplot(toyotodf['price'],kde=True)#distribution plot kde=kernel density estimation
plt.show()
sns.distplot(toyotodf['price'],kde=False,color="r")#distribution plot kde=kernel density estimation
sns.distplot(toyotodf['price'],kde=False,bins=6)#distribution plot kde=kernel density estimation
# Out:
# C:\Users\HARIHARAPRASAD R\AppData\Local\Temp\ipykernel_10644\1796862554.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(toyotodf['price'],kde=True)#distribution plot kde=kernel density estimation
# C:\Users\HARIHARAPRASAD R\AppData\Local\Temp\ipykernel_10644\1796862554.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#bar plot used to find the frequency distribution of the variable
#count plot in the sns plot 
sns.countplot(x='fueltypes',data=toyotodf)
plt.show()
#sns.countplot(x='fueltypes',data=toyotodf)

# %%
#Box and interpret plot min max median 
sns.boxplot(y=toyotodf['price'])
# Out:
# <Axes: ylabel='price'>

# %%
var='01234567'
#print(var[4::-1])
a=int(var[4::-1])
print("a is =",a)
a+=1
print("now a is",a)
# Out:
# a is = 43210
# now a is 43211

# %%
insects = ['Ants', 'Cricket', 'Bee']
a=pd.DataFrame(insects)
a
b={"name":["dhoni ","kohli"],"age":[41,38]}
s=pd.DataFrame(b)
s
# Out:
#      name  age
# 0  dhoni    41
# 1   kohli   38
