# %%
import pandas as pd

# %%
op=pd.read_csv("C:\\Users\\HARIHARAPRASAD R\\OneDrive\\All-Time-Best-Batsman.csv")

# %%
#op1=op.fillna("wwww")
op1=op.fillna(method='ffill')#forward fill
op1=op.fillna(method='bfill')#backward fill
op1=op.fillna(op['100'].mean())#fillng the mean of the column
op1["gender"]=0
op1['gender'].fillna(op1['100'].mean(),inplace=True)

# %%
#interpolite machanism basicly works column data type is on number
#interpolite will linear form by keeping current data and linear data
op_interolate=op.interpolate(method='linear')#interpolaiting missed_values with the above and belove data
op_interolate
# Out:
#      POS                Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF  \
# 0      1           Virat Kohli   RCB  237   229  34  7263   113  37.25  5586
# 1      2        Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203
# 2      3          David Warner    DC  176   176  22  6397   126  41.54  4572
# 3      4          Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776
# 4      5          Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042
# ..   ...                   ...   ...  ...   ...  ..   ...   ...    ...   ...
# 130  131  Gurkeerat Mann Singh   RCB   39    32   8   511    65  21.29   422
# 131  132         Sai Sudharsan    GT   13    13   2   507    96  46.09   370
# 132  133            Owais Shah    RR   23    22   7   506    76  33.73   389
# 133  134         Paul Valthaty  PBKS   23    23   1   505   120  22.95   418
# 134  135          Sam Billings   KKR   30    27   1   503    56  19.35   388
#
#          SR  100  50   4s   6s
# ...

# %%
#outliers
#1 diffrent values not normal
#2 skew data distribution
