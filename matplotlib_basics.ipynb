# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
x=[1,2,3,4,5]
y=[10,20,5,15,100]
r=[1,3,4,5,6]
t=[20,40,50,60,70]
plt.style.use('seaborn')
plt.xkcd()
plt.plot(x,t,'k',marker='o',label='salary')
plt.plot(x,y,color='b',marker='.',label=' age and salary')
plt.title(" age and salary ")
plt.fill_between(x,t,)
plt.grid(True)
plt.xlabel(" age")
plt.ylabel(" salery")
plt.legend(x)
plt.show()
# Out:
# C:\Users\HARIHARAPRASAD R\AppData\Local\Temp\ipykernel_7004\4153262342.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
x_index=np.arange(len(ages))
width=0.3
ages=[20,21,22,23,24,25]
python=[10000,22000,24000,30000,32000,35000]
java=[12000,13000,35000,36000,37000,40000]
plt.bar(x_index-width,python,color='b',edgecolor='white',width=width,label="py")
plt.bar(x_index+width,java,width=width,color='g',edgecolor='k',label="java")
plt.xlabel=('ages')
plt.ylabel=(" salary per month ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 x_index=np.arange(len(ages))
#       4 width=0.3
#       5 ages=[20,21,22,23,24,25]
#
# NameError: name 'ages' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use("seaborn")
slices=[60,10,30,30]
divi=['playing','sleeping','working','listining']
color=['blue','yellow','white','red']
plt.pie(slices,labels=divi, colors=color,wedgeprops={'edgecolor':'black'})
plt.title=(' pie charts')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
plt.xkcd()
slices=[59219,55466,47544,36443,35917]
lable=['javascript','html','sql','python','java']
exp=[0,0,0,0.1,0]
plt.pie(slices,labels=lable,explode=exp,shadow=True,startangle=60,autopct='%1.1f%%',wedgeprops={'edgecolor':'white'})
plt.title(" my pie chart")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
plt.grid(True)
min=[1,2,3,4,5,6,7,8,9]
color=['orange','red','blue']
plt.title(" my stack plot")
player1=[1,2,3,2,6,4,1,1,6]
player2=[1,3,4,6,6,6,1,2,3]
player3=[1,2,3,1,2,3,1,2,3]
plt.stackplot(min,player1,player2,player3,edgecolor='black',)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HARIHARAPRASAD R\AppData\Local\Temp\ipykernel_5060\896034375.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
x=[1,2,3,4,5,6,4,8,5,1,3,4,6,7,8]
y=[1,2,3,4,5,6,6,7,8,1,3,5,6,7,8]
color=[1,3,5,6,7]
plt.scatter(x,y,c='b',cmap='blue',s=100,marker='o',edgecolor='black',alpha=0.75)
cbar=plt.colorbar()
plt.show()

# %%
import matplotlib as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
