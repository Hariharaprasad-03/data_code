# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
from matplotlib import  pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\HARIHARAPRASAD R\\Downloads\\DailyDelhiClimateTrain.csv")
print(data.head())
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
print(data.max(),data.min())
# Out:
# date             2017-01-01
# meantemp          38.714286
# humidity              100.0
# wind_speed            42.22
# meanpressure    7679.333333
# dtype: object date            2013-01-01
# meantemp               6.0
# humidity         13.428571
# wind_speed             0.0
# meanpressure     -3.041667
# dtype: object

# %%
print(data.value_counts(data['humidity']),)
print(data.value_counts(data['wind_speed']))
print(data.value_counts(data['meanpressure']))
# Out:
# humidity
# 65.500000     9
# 65.750000     8
# 69.000000     7
# 67.625000     7
# 67.000000     7
#              ..
# 56.750000     1
# 56.866667     1
# 57.062500     1
# 57.133333     1
# 100.000000    1
# Name: count, Length: 897, dtype: int64
# wind_speed
# 0.000000     26
# 0.925000     24
# 1.850000     20
# 1.162500     18
# 2.550000     18
#              ..
# 6.660000      1
# 6.652941      1
# 6.625000      1
# 6.614286      1
# 42.220000     1
# Name: count, Length: 730, dtype: int64
# meanpressure
# 1017.000000    13
# 1016.000000    13
# 998.000000     12
# 1007.000000    12
# 1003.250000    12
#                ..
# 1005.590909     1
# 1005.400000     1
# 1005.375000     1
# 1005.370370     1
# 7679.333333     1
# Name: count, Length: 626, dtype: int64

# %%
sns.regplot(x=data['humidity'],y=data['meantemp'],fit_reg=True,data=data)
# Out:
# <Axes: xlabel='humidity', ylabel='meantemp'>
